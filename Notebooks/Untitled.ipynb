# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np

lena = cv2.imread('images/lena.png')
plt.imshow(cv2.cvtColor(lena, cv2.COLOR_BGR2RGB)); plt.show()
I_red = lena.copy()  # Duplicate image
I_red[:, :, 1] = 0  # Zero out contribution from green
I_red[:, :, 2] = 0    # Zero out contribution from blue
plt.imshow(I_red); plt.show()
I_green = lena.copy()
I_green[:, :, 0] = 0
I_green[:, :, 1] = 0
plt.imshow(I_green); plt.show()
I_blue = lena.copy()
I_blue[:, :, 0] = 0
I_blue[:, :, 2] = 0
plt.imshow(I_blue); plt.show()
teste = lena.copy()
teste[:,:,1] = I_blue[:,:,1]
teste[:,:,0] = I_red[:,:,0]
teste[:,:,2] = I_green[:,:,2]
plt.imshow(teste); plt.show()

cropped = lena[1]
print("teste")
print(teste[0:10,0:10])
print("lena")
print(lena[0:10,0:10])
# Out:
# teste
# [[[125 137 226]
#   [125 137 226]
#   [133 137 223]
#   [128 136 223]
#   [120 138 226]
#   [116 129 226]
#   [123 138 228]
#   [124 134 227]
#   [127 140 227]
#   [119 136 225]]
#
#  [[125 137 226]
#   [125 137 226]
#   [133 137 223]
#   [128 136 223]
#   [120 138 226]
#   [116 129 226]
#   [123 138 228]
#   [124 134 227]
#   [127 140 227]
#   [119 136 225]]
#
#  [[125 137 226]
#   [125 137 226]
#   [133 137 223]
#   [128 136 223]
#   [120 138 226]
#   [116 129 226]
#   [123 138 228]
#   [124 134 227]
#   [127 140 227]
#   [119 136 225]]
#
#  [[125 137 226]
#   [125 137 226]
#   [133 137 223]
#   [128 136 223]
#   [120 138 226]
#   [116 129 226]
#   [123 138 228]
#   [124 134 227]
#   [127 140 227]
#   [119 136 225]]
#
#  [[125 137 226]
#   [125 137 226]
#   [133 137 223]
#   [128 136 223]
#   [120 138 226]
#   [116 129 226]
#   [123 138 228]
#   [124 134 227]
#   [127 140 227]
#   [119 136 225]]
#
#  [[123 140 227]
#   [123 140 227]
#   [113 131 227]
#   [111 130 222]
# ...

# %%
r = cv2.Canny(lena,150,160)
plt.imshow(r);plt.show()
